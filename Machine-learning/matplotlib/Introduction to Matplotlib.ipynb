# %% [markdown]
# # Introduction to Matplotplib

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
plt.plot()
# Out:
# []

# %%
plt.plot();

# %%
plt.plot()
plt.show()

# %%
plt.plot([1,2,3,4]);

# %%
x = [1, 2, 3, 4]
y = [11, 22, 33, 44]
plt.plot(x, y);

# %%
# 1st method
fig = plt.figure() # creates a figure
ax = fig.add_subplot() #adds some axes
plt.show()

# %%
# 2nd method
fig = plt.figure() # creates a figure
ax = fig.add_axes([1, 1, 1, 1])
ax.plot(x,y) # add some data
plt.show()

# %%
# 3rd method (recomended)
fig, ax = plt.subplots()
ax.plot(x, [50, 100,  200, 250]); # add some data
type(fig), type(ax)
# Out:
# (matplotlib.figure.Figure, matplotlib.axes._axes.Axes)

# %% [markdown]
# ## Anatomy of a Matplot Lib
# <img src="matplotlib-anatomy-of-a-plot.png"/>
# <img src="matplotlib-anatomy-of-a-plot-with-code.png"/>
# <img src="technical_analysis.png"/>

# %% [markdown]
# # Matplotplit example workflow

# %%
# 0. import matplotlib and get it ready for plotting in Jupyter
# %matplotlib inline
import matplotlib.pyplot as plt

# 1. Prepare data
x = [1, 2, 3, 4]
y = [11, 22, 33 ,44]

# 2. Setup plot
fig, ax = plt.subplots(figsize=(5,5))

# 3. Plot data
ax.plot(x, y)

# 4. Customize plot
ax.set(title="Simple Plot",
      xlabel="x-axis",
      ylabel="y-axis")

# 5. Save & show (you save the whole figure)
fig.savefig("sample-plot.png")

# %% [markdown]
# ## Making figures with NumPy arrays
# We want:
# * Line plot
# * Scatter plot
# * Bar plto
# * Histogram
# * Subplots

# %%
import numpy as np

# %%
# Create some data
x = np.linspace(0, 10 ,100)
x[:10]
# Out:
# array([0.        , 0.1010101 , 0.2020202 , 0.3030303 , 0.4040404 ,
#        0.50505051, 0.60606061, 0.70707071, 0.80808081, 0.90909091])

# %%
# Plot the data in a line plot
fig, ax = plt.subplots()
ax.plot(x, x**2);

# %%
# Use the same data to make a scatter plot
figure, ax = plt.subplots()
ax.scatter(x, np.exp(x))

# %%
# Another scatter plot
fig, ax = plt.subplots()
ax.scatter(x, np.cos(x))

# %%
# Make a plot from a dictionary
nut_butter_prices = {"Almond butter": 10,
                     "Peanut Butter": 8,
                     "Cashew Butter": 12}
fig, ax = plt.subplots()
ax.bar(nut_butter_prices.keys(), nut_butter_prices.values())
ax.set(title="Lorenzo's Nut Butter Store",
      ylabel="Price ($)",);

# %%
fig, ax = plt.subplots()
ax.barh(list(nut_butter_prices.keys()), list(nut_butter_prices.values()))
# Out:
# <BarContainer object of 3 artists>

# %%
# Make some data for histogram
x = np.random.randn(1000)
fix, ax = plt.subplots()
ax.hist(x);

# %% [markdown]
# ## Two options for subplots

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2,
                                            ncols=2,
                                            figsize=(10,5))
# Plot to each different axis
ax1.plot(x, x/2);
ax2.scatter(np.random.random(10), np.random.random(10));
ax3.bar(nut_butter_prices.keys(), nut_butter_prices.values());
ax4.hist(np.random.randn(1000));

# %%
# Subplots option 2
fig, ax = plt.subplots(nrows=2,
                      ncols=2,
                      figsize=(10,5))

# Plot to each different index
ax[0, 0].plot(x, x/2);
ax[0, 1].scatter(np.random.random(10), np.random.random(10));
ax[1, 0].bar(nut_butter_prices.keys(), nut_butter_prices.values());
ax[1, 1].hist(np.random.randn(1000));

# %% [markdown]
# ## Ploting ftom pandas DatafFrames

# %%
import pandas as pd

# %%
#Make a dataframe
car_sales = pd.read_csv("car-sales.csv")

# %%
ts = pd.Series(np.random.randn(1000),
               index=pd.date_range("7/30/2024", periods=1000))
ts = ts.cumsum()

ts.plot()
# Out:
# <Axes: >

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors Price
# 0  Toyota  White         150043      4    40
# 1   Honda    Red          87899      4    50
# 2  Toyota   Blue          32549      3    70
# 3     BMW  Black          11179      5   220
# 4  Nissan  White         213095      4    35
# 5  Toyota  Green          99213      4    45
# 6   Honda   Blue          45698      4    75
# 7   Honda   Blue          54738      4    70
# 8  Toyota  White          60000      4    62
# 9  Nissan  White          31600      4    97

# %%
car_sales["Price"] = car_sales["Price"].str.replace(r'[\$\,\.]', '', regex=True)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
car_sales["Price"] = car_sales["Price"].str[:-2]
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
car_sales["Sale Date"] = pd.date_range("7/30/2024", periods=len(car_sales))
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date
# 0  Toyota  White         150043      4   4000 2024-07-30
# 1   Honda    Red          87899      4   5000 2024-07-31
# 2  Toyota   Blue          32549      3   7000 2024-08-01
# 3     BMW  Black          11179      5  22000 2024-08-02
# 4  Nissan  White         213095      4   3500 2024-08-03
# 5  Toyota  Green          99213      4   4500 2024-08-04
# 6   Honda   Blue          45698      4   7500 2024-08-05
# 7   Honda   Blue          54738      4   7000 2024-08-06
# 8  Toyota  White          60000      4   6250 2024-08-07
# 9  Nissan  White          31600      4   9700 2024-08-08

# %%
car_sales["Total Sales"] = car_sales["Price"].astype(int).cumsum()
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000 2024-07-30         4000
# 1   Honda    Red          87899      4   5000 2024-07-31         9000
# 2  Toyota   Blue          32549      3   7000 2024-08-01        16000
# 3     BMW  Black          11179      5  22000 2024-08-02        38000
# 4  Nissan  White         213095      4   3500 2024-08-03        41500
# 5  Toyota  Green          99213      4   4500 2024-08-04        46000
# 6   Honda   Blue          45698      4   7500 2024-08-05        53500
# 7   Honda   Blue          54738      4   7000 2024-08-06        60500
# 8  Toyota  White          60000      4   6250 2024-08-07        66750
# 9  Nissan  White          31600      4   9700 2024-08-08        76450

# %%
# Let's plot the total sales
car_sales.plot(x="Sale Date", y="Total Sales");

# %%
car_sales["Price"] = car_sales["Price"].astype(int)
car_sales.plot(x="Odometer (KM)", y="Price", kind="scatter");

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000 2024-07-30         4000
# 1   Honda    Red          87899      4   5000 2024-07-31         9000
# 2  Toyota   Blue          32549      3   7000 2024-08-01        16000
# 3     BMW  Black          11179      5  22000 2024-08-02        38000
# 4  Nissan  White         213095      4   3500 2024-08-03        41500
# 5  Toyota  Green          99213      4   4500 2024-08-04        46000
# 6   Honda   Blue          45698      4   7500 2024-08-05        53500
# 7   Honda   Blue          54738      4   7000 2024-08-06        60500
# 8  Toyota  White          60000      4   6250 2024-08-07        66750
# 9  Nissan  White          31600      4   9700 2024-08-08        76450

# %%
car_sales.plot(x="Sale Date", y="Price", kind="bar");

# %%
x = np.random.rand(10, 4)
x

df = pd.DataFrame(x, columns=(["a", "b", "c", "d"]))
df
# Out:
#           a         b         c         d
# 0  0.043295  0.345962  0.201940  0.472581
# 1  0.647784  0.495846  0.690897  0.281495
# 2  0.906988  0.240641  0.656984  0.294711
# 3  0.778381  0.932912  0.490786  0.323159
# 4  0.860330  0.669147  0.992359  0.150041
# 5  0.003037  0.280231  0.220044  0.217364
# 6  0.922003  0.625635  0.549902  0.842801
# 7  0.217079  0.814767  0.746606  0.400298
# 8  0.504527  0.527887  0.492974  0.904241
# 9  0.240823  0.369186  0.949404  0.389189

# %%
df.plot.bar();

# %%
df.plot(kind="bar");

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000 2024-07-30         4000
# 1   Honda    Red          87899      4   5000 2024-07-31         9000
# 2  Toyota   Blue          32549      3   7000 2024-08-01        16000
# 3     BMW  Black          11179      5  22000 2024-08-02        38000
# 4  Nissan  White         213095      4   3500 2024-08-03        41500
# 5  Toyota  Green          99213      4   4500 2024-08-04        46000
# 6   Honda   Blue          45698      4   7500 2024-08-05        53500
# 7   Honda   Blue          54738      4   7000 2024-08-06        60500
# 8  Toyota  White          60000      4   6250 2024-08-07        66750
# 9  Nissan  White          31600      4   9700 2024-08-08        76450

# %%
car_sales.plot(x="Make", y="Odometer (KM)", kind="bar")
# Out:
# <Axes: xlabel='Make'>

# %%
# How about histograms

car_sales["Odometer (KM)"].plot.hist();

# %%
car_sales["Odometer (KM)"].plot(kind="hist");

# %%
car_sales["Odometer (KM)"].plot.hist(bins=10);

# %%
# Let's try on another data set
heart_disease = pd.read_csv("heart-disease.csv")
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
# Create a histogram of age
heart_disease["age"].plot.hist(bins=10);

# %%
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
heart_disease.plot.hist(figsize=(10,30), subplots=True);

# %% [markdown]
# ### Which one should you use? (pyplot vs matplotlib OO method)
#
# * When plotting something quickly, okay to use pyplot method
# * When plotting something more advanced, use the object-oriented method

# %%
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
over_50 = heart_disease[heart_disease["age"] > 50]
over_50.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
# Pyplot method
over_50.plot(kind="scatter",
            x="age",
            y="chol",
            c="target");

# %%
# OO method
fig, ax = plt.subplots(figsize=(10, 6))
over_50.plot(kind="scatter",
            x="age",
            y="chol",
            c="target",
            ax=ax);
# ax.set_xlim([45, 100])

# %%
fig, ax = plt.subplots(figsize=(10,6))
scatter = ax.scatter(x=over_50["age"],
                     y=over_50["chol"],
                     c=over_50["target"]);

ax.set(title="Heart Disease and Cholestetol levels",
      xlabel="Age",
      ylabel="Cholesterol");

ax.legend(*scatter.legend_elements(), title="Target");

ax.axhline(over_50["chol"].mean(),
          linestyle="--");

# %%
over_50.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
fig, ax = plt.subplots(figsize=(10,6))
scatter = ax.scatter(x=over_50["age"],
                    y=over_50["thalach"],
                    c=over_50["target"],
                    cmap="winter");

ax.set(title="Heart Disease and Max Heart Rate",
      xlabel="Age",
      ylabel="Max Heart Rate");

ax.legend(*scatter.legend_elements(), title="Target");

ax.axhline(over_50["thalach"].mean(),
          linestyle=("--"));

# %%
plt.style.use("seaborn-v0_8-whitegrid")
fig, (ax0, ax1) = plt.subplots(nrows=2,
                                ncols=1,
                                figsize=(10,10),
                                sharex=True)

# fig.tight_layout(pad=5)

# Ax0 -------------------------------------------------------
ax0.scatter(x=over_50["age"],
                     y=over_50["chol"],
                     c=over_50["target"],
                     cmap="winter");

ax0.set(title="Heart Disease and Cholestetol levels",
      ylabel="Cholesterol");

ax0.legend(*scatter.legend_elements(), title="Target");

ax0.axhline(over_50["chol"].mean(),
          linestyle="--");
# Ax1-----------------------------------------------------------
scatter1 = ax1.scatter(x=over_50["age"],
                    y=over_50["thalach"],
                    c=over_50["target"],
                    cmap="winter");

ax1.set(title="Heart Disease and Max Heart Rate",
      xlabel="Age",
      ylabel="Max Heart Rate");

ax1.legend(*scatter.legend_elements(), title="Target");

ax1.axhline(over_50["thalach"].mean(),
          linestyle=("--"));

# ---------------------------------------------------------------
fig.suptitle("Heart Disease Analysis", fontsize=16, fontweight="bold")
# Out:
# Text(0.5, 0.98, 'Heart Disease Analysis')

# %%
fig.savefig("heart-disease-analysis-plot.png")

# %% [markdown]
# ## Customizing MatplotLib plots and getting stylish

# %%
# See the different styles available
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000 2024-07-30         4000
# 1   Honda    Red          87899      4   5000 2024-07-31         9000
# 2  Toyota   Blue          32549      3   7000 2024-08-01        16000
# 3     BMW  Black          11179      5  22000 2024-08-02        38000
# 4  Nissan  White         213095      4   3500 2024-08-03        41500

# %%
car_sales["Price"].plot();

# %%
plt.style.use("seaborn-v0_8-whitegrid")

# %%
car_sales["Price"].plot();

# %%
plt.style.use("seaborn-v0_8")

# %%
car_sales["Price"].plot()
# Out:
# <Axes: >

# %%
car_sales.plot(x="Odometer (KM)", y="Price", kind="scatter")
# Out:
# <Axes: xlabel='Odometer (KM)', ylabel='Price'>

# %%
plt.style.use("ggplot")

# %%
car_sales["Price"].plot();

# %%
# Create some data
x = np.random.randn(10, 4)
x
# Out:
# array([[ 0.52257047,  1.75761367, -1.50872099,  1.07753724],
#        [-0.44970113,  1.041548  ,  0.83418225,  0.87123776],
#        [ 0.08423556, -0.81634807, -0.46576175,  0.07060774],
#        [ 1.38081153, -0.80203931,  1.45147045, -0.19574112],
#        [ 1.15404039,  1.02057387, -0.43063009, -1.60860067],
#        [ 0.67008242, -1.13650946, -0.07326983,  1.15529456],
#        [ 0.78205386,  0.15801885,  0.55419673, -0.39275241],
#        [ 1.14624429, -0.72145679, -2.27231031, -0.89621731],
#        [-0.85520195,  0.82041409,  0.89093802, -1.03771082],
#        [ 0.13196089, -0.2459897 , -1.43549347,  0.82846266]])

# %%
df = pd.DataFrame(x, columns=["a", "b", "c", "d"])
df
# Out:
#           a         b         c         d
# 0  0.522570  1.757614 -1.508721  1.077537
# 1 -0.449701  1.041548  0.834182  0.871238
# 2  0.084236 -0.816348 -0.465762  0.070608
# 3  1.380812 -0.802039  1.451470 -0.195741
# 4  1.154040  1.020574 -0.430630 -1.608601
# 5  0.670082 -1.136509 -0.073270  1.155295
# 6  0.782054  0.158019  0.554197 -0.392752
# 7  1.146244 -0.721457 -2.272310 -0.896217
# 8 -0.855202  0.820414  0.890938 -1.037711
# 9  0.131961 -0.245990 -1.435493  0.828463

# %%
ax = df.plot(kind="bar")
type(ax)
# Out:
# matplotlib.axes._axes.Axes

# %%
#Customize our plot with the set method
ax = df.plot(kind="bar")
ax.set(title="Random Number Bar Graph from DataFrame",
      xlabel="Row Number",
      ylabel="Random Number");
ax.legend().set_visible(True)
